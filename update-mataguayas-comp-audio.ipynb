# %% [markdown]
# # Actualizar datos audio cuadro mataguayas comparadas
#
# **nov-2023**
#
# Actualización de datos de transcripciones del cuadro de audio de página de [Resultados](https://dila-caicyt.github.io/pict-glotales/resultados/) del sitio del proyecto en Github https://dila-caicyt.github.io/pict-glotales.
#
# - datos del cuadro: [mataguayas-comparadas-audio.csv](../pict-glotales/_data/mataguayas-comparadas-audio.csv)
# - spreadsheet colaborativa a partir de la cual se obtienen los datos: [palabras_en_comun_audios](https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc/edit#gid=1308046217)
#
# Actualización post revisión de AG de toda la spreadsheet.

# %%
import pandas as pd

# %%
## SPREADSHEET
gsheet = "https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc/export?gid=1308046217&format=csv" ## CAICYT
gsheet = "palabras_en_comun_audios.csv" ## BELERIAND

## OUT
ghdir = "../pict-glotales/_data" ## Repertorio del sitio Github

# %%
comun_audio =  pd.read_csv(gsheet)
comun_audio.sample(5)
# Out:
#     Palabra   Lengua Español                     Recorte  \
# 19    inʲoɁ  chorote  hombre                  07B_hombre
# 130  jit'oχ  nivacle  mi tía         20120316FR091_mitia
# 101    wɑ̰s  nivacle   cielo  2010_08_21_FR_AG_052_cielo
# 13    jiɬeʔ     maka   piojo                    ma_iilhe
# 51    peɁel  chorote  sombra       CRT001R031I001_sombra
#
#                   Archivo Formato Inicio (sg) Fin (sg)  Código  \
# 19            cinta07_B_1     wav     353.559  354.982  PP2005
# 130    20120316_FR_AG_091     wav         NaN      NaN  Gu2012
# 101  2010_08_21_FR_AG_052     wav         NaN      NaN  Gu2010
# 13         MCA001R024I002     wav     540.033  541.071   G1985
# 51        CRT001R031I001      wav     425.546  426.665   G1968
#
#             Cita Audio  ...  \
# 19         Pacor, 2005  ...
# 130    Gutiérrez, 2012  ...
# 101    Gutiérrez, 2010  ...
# 13   Gerzenstein, 1985  ...
# 51   Gerzenstein, 1968  ...
#
#                                     Cita Bibliográfica  Herramienta  \
# 19   Pacor, Paola. (2005). Trabajo de campo lengua ...  Transcriber
# 130  Gutiérrez, Analía (2012) Trabajo de campo sobr...         Word
# 101  Gutiérrez, Analía (2010) Trabajo de campo sobr...         Word
# 13   Gerzenstein, Ana. (1985). Elicitación. Texas, ...  Transcriber
# 51   Gerzenstein, Ana. (1968) "Palabras en Chorote"...  Transcriber
#
#     Transcriptorx    Tanda Revisorx    Fuente        Consultante  \
# 19          GG-PP  2019-10       AG  DILA inv       Enrique Díaz
# 130            AG  2023-08       AG  DILA inv      Félix Ramírez
# 101            AG  2023-08       AG  DILA inv      Félix Ramírez
# 13             MD  2019-06       AG     AILLA  T'semhej, Andrés
# 51             PP  2023-08      NaN     AILLA   Manuel González
#
#                                              Comunidad    Latitud   Longitud
# 19   Misión Nueva Esperanza, Santa Victoria Este, S... -22.276560 -62.712910
# 130                  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.050070
# 101                  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.050070
# 13                                  Asunción, Paraguay -25.296674 -57.680663
# 51   Misión La Paz, Santa Victoria Este, Salta, 5 d... -22.368465 -62.561983
#
# [5 rows x 21 columns]

# %% [markdown]
# Sacamos espacios en blanco al final del nombre del archivo de recorte de audio que se sube al sitio:

# %%
comun_audio['Recorte'] = comun_audio['Recorte'].str.strip()

# %% [markdown]
# Los datos del cuadro de mataguayas comparadas están organizados así:

# %%
mataguayas_comp_audio = pd.read_csv(f"{ghdir}/mataguayas-comparadas-audio.csv")
mataguayas_comp_audio.sample(3)
# Out:
#      espanol chorote     fuente_chorote           audio_chorote         maka  \
# 77   ustedes  asaɁam  Gerzenstein, 1968  CRT001R032I001_ustedes  inekheβeliɬ
# 63     piojo  inɬaʔa        Bucca, 1969            ch_in_xlha_a        jiɬeʔ
# 38  mi nieta     NaN                NaN                     NaN        jukiɁ
#
#           fuente_maka              audio_maka       nivacle   fuente_nivacle  \
# 77  Gerzenstein, 1985  MCA001R024I001_ustedes  aβa̰tt͡ʃeʔeɬ  Gutiérrez, 2011
# 63  Gerzenstein, 1985                ma_iilhe         ɬaɬaʔ      Bucca, 1969
# 38  Gerzenstein, 1985  MCA001R024I001_minieta           NaN              NaN
#
#             audio_nivacle wichi fuente_wichi audio_wichi
# 77  20110712FR071_ustedes   NaN          NaN         NaN
# 63              ni_lhalha   ɬaʔ  Bucca, 1969      wi_lha
# 38                    NaN   NaN          NaN         NaN

# %%
len(mataguayas_comp_audio)
# Out:
# 84

# %% [markdown]
# Seleccionamos las columnas que necesitamos de df de datos colaborativos:

# %%
comun_audio = comun_audio[['Español','Lengua' ,'Palabra','Cita Audio', 'Recorte']]
comun_audio.sample(5)
# Out:
#          Español   Lengua   Palabra         Cita Audio  \
# 79           sol     maka     xunuɁ  Gerzenstein, 1985
# 105      mi mano  nivacle  jipɑʔkɑt    Gutiérrez, 2019
# 13         piojo     maka     jiɬeʔ  Gerzenstein, 1985
# 124  mi costilla  nivacle    jiβɬiʔ    Gutiérrez, 2011
# 131      su cara  nivacle     ɬtako    Gutiérrez, 2012
#
#                       Recorte
# 79         MCA001R024I001_sol
# 105     20190720FR056_mi_mano
# 13                   ma_iilhe
# 124  20110711FR203_micostilla
# 131      20120317FR003_sucara

# %% [markdown]
# Tenemos que ir lengua por lengua. Empezamos añadiendo las palabras en chorote:

# %%
chorote = comun_audio[comun_audio['Lengua'] == 'chorote']
chorote.drop(columns='Lengua', inplace=True)
chorote = chorote.rename(columns={"Español":"espanol", "Cita Audio":"fuente_chorote", "Palabra":"chorote", "Recorte":"audio_chorote"})
print(f"Tenemos {len(chorote)} palabras en chorote para el cuadro de audio")
chorote.sample(5)
# Out:
# Tenemos 59 palabras en chorote para el cuadro de audio
# /home/yoki/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       espanol chorote     fuente_chorote            audio_chorote
# 50        sol  kilʲeɁ  Gerzenstein, 1968       CRT001R031I001_sol
# 51     sombra   peɁel  Gerzenstein, 1968    CRT001R031I001_sombra
# 44  mi cuello   tijoɁ  Gerzenstein, 1968  CRT001R007I002_micuello
# 34       luna   weɁla        Pacor, 2005                 01A_luna
# 37     paloma   ohʷoɁ  Gerzenstein, 1968    CRT001R007I001_paloma

# %% [markdown]
# Ahora recuperamos las palabras en maka y las agregamos al nuevo df:

# %%
maka = comun_audio[comun_audio['Lengua'] == 'maka']
maka.drop(columns='Lengua', inplace=True)
maka = maka.rename(columns={"Español":"espanol", "Cita Audio":"fuente_maka", "Palabra":"maka", "Recorte":"audio_maka"})
print(f"Tenemos {len(maka)} palabras maka para el cuadro de audio")
maka.sample(5)
# Out:
# Tenemos 27 palabras maka para el cuadro de audio
# /home/yoki/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         espanol     maka        fuente_maka                 audio_maka
# 88     mi talón  joqoq'o  Gerzenstein, 1985     MCA001R024I001_mitalon
# 13        piojo    jiɬeʔ  Gerzenstein, 1985                   ma_iilhe
# 76  mi costilla  jiweɬiɁ  Gerzenstein, 1985  MCA001R024I001_micostilla
# 74     mi oreja   jikfiɁ  Gerzenstein, 1985     MCA001R024I001_mioreja
# 73       mi ojo    jitoɁ  Gerzenstein, 1985       MCA001R024I001_miojo

# %%
new_mataguayas_comp = chorote.merge(maka, how="outer", on="espanol")
new_mataguayas_comp#[30:40]
# Out:
#        espanol chorote fuente_chorote audio_chorote     maka  \
# 0         flor   ɬokʲe    Bucca, 1969     ch_xlokje   ɬopʼom
# 1        fruta    ɬaʔa    Bucca, 1969      ch_lha_a      ɬeɁ
# 2      su hija    ɬɑse    Bucca, 1969     ch_lhaxse      NaN
# 3      mi hija    jase    Bucca, 1969      ch_jaxse      NaN
# 4        piojo  inɬaʔa    Bucca, 1969  ch_in_xlha_a    jiɬeʔ
# ..         ...     ...            ...           ...      ...
# 67  mi corazón     NaN            NaN           NaN  jiɬitiɁ
# 68      sangre     NaN            NaN           NaN  jathits
# 69        nube     NaN            NaN           NaN    wasiɁ
# 70       cuero     NaN            NaN           NaN     ɬɁax
# 71     escucho     NaN            NaN           NaN  eɁpiyeɁ
#
#           fuente_maka                audio_maka
# 0   Gerzenstein, 1985               ma_lh_op_om
# 1   Gerzenstein, 1985      MCA001R024I001_fruta
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4   Gerzenstein, 1985                  ma_iilhe
# ..                ...                       ...
# 67  Gerzenstein, 1985  MCA001R024I001_micorazon
# 68  Gerzenstein, 1985   MCA001R024I001_misangre
# 69  Gerzenstein, 1985       MCA001R024I001_nube
# 70  Gerzenstein, 1985      MCA001R024I001_cuero
# 71  Gerzenstein, 1984  MCA001R015I001_yoescucho
#
# [72 rows x 7 columns]

# %% [markdown]
# Ahora añadimos datos nivacle:

# %%
nivacle = comun_audio[comun_audio['Lengua'] == 'nivacle']
nivacle.drop(columns='Lengua', inplace=True)
nivacle = nivacle.rename(columns={"Español":"espanol", "Cita Audio":"fuente_nivacle", "Palabra":"nivacle", "Recorte":"audio_nivacle"})
print(f"Tenemos {len(nivacle)} palabras nivacle para el cuadro de audio")
nivacle.sample(5)
# Out:
# Tenemos 48 palabras nivacle para el cuadro de audio
# /home/yoki/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#               espanol     nivacle   fuente_nivacle  \
# 122  mi hermana menor  jit͡ʃ'inxɑ  Gutiérrez, 2011
# 121             tarde       nuʔut  Gutiérrez, 2010
# 100              niño     nekxɑ̰k  Gutiérrez, 2017
# 97             sombra      ɬaxpek  Gutiérrez, 2012
# 94         mi sobrino   jifak͡lʔa  Gutiérrez, 2012
#
#                     audio_nivacle
# 122  20110708ER071_mihermanamenor
# 121           20100831FR042_tarde
# 100       20170404FR_AG_087_ninio
# 97      20120505_FR_AG_063_sombra
# 94   20120308_FR_AG_070_misobrino

# %%
new_mataguayas_comp = new_mataguayas_comp.merge(nivacle, how="outer", on="espanol")
new_mataguayas_comp
# Out:
#       espanol chorote fuente_chorote audio_chorote    maka        fuente_maka  \
# 0        flor   ɬokʲe    Bucca, 1969     ch_xlokje  ɬopʼom  Gerzenstein, 1985
# 1       fruta    ɬaʔa    Bucca, 1969      ch_lha_a     ɬeɁ  Gerzenstein, 1985
# 2     su hija    ɬɑse    Bucca, 1969     ch_lhaxse     NaN                NaN
# 3     mi hija    jase    Bucca, 1969      ch_jaxse     NaN                NaN
# 4       piojo  inɬaʔa    Bucca, 1969  ch_in_xlha_a   jiɬeʔ  Gerzenstein, 1985
# ..        ...     ...            ...           ...     ...                ...
# 78  su cuello     NaN            NaN           NaN     NaN                NaN
# 79    su codo     NaN            NaN           NaN     NaN                NaN
# 80      tarde     NaN            NaN           NaN     NaN                NaN
# 81     mi tía     NaN            NaN           NaN     NaN                NaN
# 82    su cara     NaN            NaN           NaN     NaN                NaN
#
#               audio_maka    nivacle   fuente_nivacle           audio_nivacle
# 0            ma_lh_op_om       ɬawa      Bucca, 1969                ni_lhavo
# 1   MCA001R024I001_fruta        ɬaj      Bucca, 1969                 ni_lhai
# 2                    NaN       ɬɑse  Gutiérrez, 2012    20120313FR136_suhija
# 3                    NaN       jɑse  Gutiérrez, 2019   20190723TeS025_mihija
# 4               ma_iilhe      ɬaɬaʔ      Bucca, 1969               ni_lhalha
# ..                   ...        ...              ...                     ...
# 78                   NaN     ɬaʔβoʔ  Gutiérrez, 2010  20100824FR183_sucuello
# 79                   NaN  t'afkatoʔ  Gutiérrez, 2010      20100824FR192_codo
# 80                   NaN      nuʔut  Gutiérrez, 2010     20100831FR042_tarde
# 81                   NaN     jit'oχ  Gutiérrez, 2012     20120316FR091_mitia
# 82                   NaN      ɬtako  Gutiérrez, 2012    20120317FR003_sucara
#
# [83 rows x 10 columns]

# %% [markdown]
# Ahora los datos de wichi:

# %%
wichi = comun_audio[comun_audio['Lengua'] == 'wichi']
wichi.drop(columns='Lengua', inplace=True)
wichi = wichi.rename(columns={"Español":"espanol", "Cita Audio":"fuente_wichi", "Palabra":"wichi", "Recorte":"audio_wichi"})
print(f"Tenemos {len(wichi)} palabras wichi para el cuadro de audio")
wichi.sample(4)
# Out:
# Tenemos 4 palabras wichi para el cuadro de audio
# /home/yoki/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     espanol  wichi fuente_wichi audio_wichi
# 2      flor  ɬawoʔ  Bucca, 1969   wi_lhaawo
# 12    piojo    ɬaʔ  Bucca, 1969      wi_lha
# 9   su hija   ɬɑse  Bucca, 1969  wi_olhaase
# 6     fruta    ɬaj  Bucca, 1969     wi_lhai

# %%
new_mataguayas_comp = new_mataguayas_comp.merge(wichi, how="outer", on="espanol")
new_mataguayas_comp
# Out:
#       espanol chorote fuente_chorote audio_chorote    maka        fuente_maka  \
# 0        flor   ɬokʲe    Bucca, 1969     ch_xlokje  ɬopʼom  Gerzenstein, 1985
# 1       fruta    ɬaʔa    Bucca, 1969      ch_lha_a     ɬeɁ  Gerzenstein, 1985
# 2     su hija    ɬɑse    Bucca, 1969     ch_lhaxse     NaN                NaN
# 3     mi hija    jase    Bucca, 1969      ch_jaxse     NaN                NaN
# 4       piojo  inɬaʔa    Bucca, 1969  ch_in_xlha_a   jiɬeʔ  Gerzenstein, 1985
# ..        ...     ...            ...           ...     ...                ...
# 78  su cuello     NaN            NaN           NaN     NaN                NaN
# 79    su codo     NaN            NaN           NaN     NaN                NaN
# 80      tarde     NaN            NaN           NaN     NaN                NaN
# 81     mi tía     NaN            NaN           NaN     NaN                NaN
# 82    su cara     NaN            NaN           NaN     NaN                NaN
#
#               audio_maka    nivacle   fuente_nivacle           audio_nivacle  \
# 0            ma_lh_op_om       ɬawa      Bucca, 1969                ni_lhavo
# 1   MCA001R024I001_fruta        ɬaj      Bucca, 1969                 ni_lhai
# 2                    NaN       ɬɑse  Gutiérrez, 2012    20120313FR136_suhija
# 3                    NaN       jɑse  Gutiérrez, 2019   20190723TeS025_mihija
# 4               ma_iilhe      ɬaɬaʔ      Bucca, 1969               ni_lhalha
# ..                   ...        ...              ...                     ...
# 78                   NaN     ɬaʔβoʔ  Gutiérrez, 2010  20100824FR183_sucuello
# 79                   NaN  t'afkatoʔ  Gutiérrez, 2010      20100824FR192_codo
# 80                   NaN      nuʔut  Gutiérrez, 2010     20100831FR042_tarde
# 81                   NaN     jit'oχ  Gutiérrez, 2012     20120316FR091_mitia
# 82                   NaN      ɬtako  Gutiérrez, 2012    20120317FR003_sucara
#
#     wichi fuente_wichi audio_wichi
# 0   ɬawoʔ  Bucca, 1969   wi_lhaawo
# 1     ɬaj  Bucca, 1969     wi_lhai
# 2    ɬɑse  Bucca, 1969  wi_olhaase
# 3     NaN          NaN         NaN
# 4     ɬaʔ  Bucca, 1969      wi_lha
# ..    ...          ...         ...
# 78    NaN          NaN         NaN
# 79    NaN          NaN         NaN
# 80    NaN          NaN         NaN
# 81    NaN          NaN         NaN
# 82    NaN          NaN         NaN
#
# [83 rows x 13 columns]

# %%
new_mataguayas_comp = new_mataguayas_comp.sort_values(by="espanol")
new_mataguayas_comp
# Out:
#       espanol      chorote     fuente_chorote             audio_chorote maka  \
# 38       agua        inʲɑt  Gerzenstein, 1968       CRT001R031I001_agua  NaN
# 22       aire      laɁxaut        Pacor, 2005                  01A_aire  NaN
# 26  algarrobo     hʷaɁajuk  Gerzenstein, 1968  CRT001R007I001_algarrobo  NaN
# 16  brazalete     inkʲotak        Pacor, 2005             03B_brazalete  NaN
# 43     camino         nɑji  Gerzenstein, 1968     CRT001R031I001_camino  NaN
# ..        ...          ...                ...                       ...  ...
# 18       yica        ineɁe        Pacor, 2005                  03B_yica  NaN
# 15         yo        jaɁam        Pacor, 2005                    07B_yo  NaN
# 19     zapato  insaɁtitʼoɁ        Pacor, 2005                03B_zapato  NaN
# 53      árbol        aɁlaɁ  Gerzenstein, 1968      CRT001R032I001_arbol  NaN
# 55         él       hlaɁam  Gerzenstein, 1968         CRT001R032I001_el  NaN
#
#    fuente_maka audio_maka   nivacle   fuente_nivacle  \
# 38         NaN        NaN    jinɑ̰t  Gutiérrez, 2012
# 22         NaN        NaN   βatajaɬ  Gutiérrez, 2012
# 26         NaN        NaN    fa̰juk  Gutiérrez, 2011
# 16         NaN        NaN       NaN              NaN
# 43         NaN        NaN     nɑjiʃ  Gutiérrez, 2017
# ..         ...        ...       ...              ...
# 18         NaN        NaN   k͡lisaʔ  Gutiérrez, 2010
# 15         NaN        NaN       NaN              NaN
# 19         NaN        NaN       NaN              NaN
# 53         NaN        NaN  a̰kxijuk  Gutiérrez, 2011
# 55         NaN        NaN       NaN              NaN
#
#                 audio_nivacle wichi fuente_wichi audio_wichi
# 38         20120315FR041_agua   NaN          NaN         NaN
# 22         20120514FR169_aire   NaN          NaN         NaN
# 26    20110718JR072_algarrobo   NaN          NaN         NaN
# 16                        NaN   NaN          NaN         NaN
# 43       20170506FR088_camino   NaN          NaN         NaN
# ..                        ...   ...          ...         ...
# 18  2010_07_01_SR_AG_002_yica   NaN          NaN         NaN
# 15                        NaN   NaN          NaN         NaN
# 19                        NaN   NaN          NaN         NaN
# 53        20110712FR075_arbol   NaN          NaN         NaN
# 55                        NaN   NaN          NaN         NaN
#
# [83 rows x 13 columns]

# %%
new_mataguayas_comp[new_mataguayas_comp['espanol']== 'sol']
# Out:
#    espanol chorote     fuente_chorote       audio_chorote   maka  \
# 40     sol  kilʲeɁ  Gerzenstein, 1968  CRT001R031I001_sol  xunuɁ
#
#           fuente_maka          audio_maka      nivacle   fuente_nivacle  \
# 40  Gerzenstein, 1985  MCA001R024I001_sol  xunkuk͡la̰j  Gutiérrez, 2017
#
#         audio_nivacle wichi fuente_wichi audio_wichi
# 40  20170407FR061_sol   NaN          NaN         NaN

# %% [markdown]
# Guardamos en el repo del proyecto:

# %%
new_mataguayas_comp.to_csv(f"{ghdir}/mataguayas-comparadas-audio.csv", index=False)
