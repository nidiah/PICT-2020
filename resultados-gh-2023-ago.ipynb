# %% [markdown]
# # Resultados sitio Github 2023-08
#
# Modificar datos de página de [Resultados](https://dila-caicyt.github.io/pict-glotales/resultados/) del sitio del proyecto en Github https://dila-caicyt.github.io/pict-glotales.
#
# * Indicaciones para Nivaclé: https://docs.google.com/document/d/1zcsRY4r3MEmpbTVOF9NxW0hB3Gv4282jwIhRNTLsGkc/edit
# 1. La columna ID Audio es el ID de los csv de TCFiladelfia
# 2. Código: Gu2012, Cita Audio: Gutiérrez_añodecampaña > Gutiérrez_2012, Cita Bibliográfica: tesis Gutiérrez 2015
# 3. Qué criterio para nombrar los Recortes: nombredelarchivofuenteresumido_glosaenespañol. Ej. 20120318_003_algarrobo
# 4. Criterio de corte
# - Que sean en .wav
# - Dejar ~0.35/0.50 seg  de silencio al ppio y final
# 5. Resultados en:
# - https://docs.google.com/spreadsheets/d/1resasym4ZmqI7xytQknT8Veeh_1tBgOfOU_mwCQ2EVE/edit#gid=0
# - https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc/edit#gid=1308046217
#
#
# * Indicaciones para Chorote: https://docs.google.com/document/d/1wvN9SyhUMFsnvrfmFhIJLdxvhtZvkM-QSXsn5XHlc34/edit
#
# * Indicaciones para Maká: https://docs.google.com/document/d/1rnU_a122J2RVl30rU65rmekuHmGg9GuPtBJZ1C7XafA/edit

# %%
import pandas as pd
import re
import numpy as np

# %%
## IN
tcfildir = "../Nivacle/TCFiladelfia" ## Repertorio de TCFiladelfia
## OUT
ghdir = "../pict-glotales/_data" ## Repertorio del sitio Github

langs = ["wichi", "chorote", "nivacle", "maka"]

# %% [markdown]
# ## 1. Encontrar palabras seleccionadas en TCFiladelfia y llenar info en df de selección de recortes

# %% [markdown]
# Selección de palabras hecha por AG:

# %%
## Selección de palabras hecha por AG:
gsheet = "https://docs.google.com/spreadsheets/d/1resasym4ZmqI7xytQknT8Veeh_1tBgOfOU_mwCQ2EVE/export?gid=0&format=csv"
gsheet = "Palabras_Nivacle_TCFiladelfia.csv" 
sel_niv = pd.read_csv(gsheet)

# %%
sel_niv.head()
# Out:
#       Español                                 Palabra              ID Audio  \
# 0        yica                                ɬk͡lasaʔ  2011_07_08_ER_AG_125
# 1      iguana                                     aɬu  2012_05_04_GR_AG_037
# 2    langosta                                   fanxa  2012_03_13_FR_AG_140
# 3  mi sobrino  jifak͡lʔa afak͡lʔa ɬfak͡lʔa kasfak͡lʔa  2012_03_08_FR_AG_070
# 4  mi sobrina                              jifakt͡ʃḛ  2012_03_08_FR_AG_069
#
#    Inicio (sg)  Fin (sg)   Lengua Transcriptorx Herramienta    Tanda  \
# 0          NaN       NaN  nivacle            AG        Word  2023-08
# 1          NaN       NaN  nivacle            AG        Word  2023-08
# 2          NaN       NaN  nivacle            AG        Word  2023-08
# 3          NaN       NaN  nivacle            AG        Word  2023-08
# 4          NaN       NaN  nivacle            AG        Word  2023-08
#
#   Repositorio  Código      Cita Audio  \
# 0    DILA inv  Gu2011  Gutiérrez_2011
# 1    DILA inv  Gu2012  Gutiérrez_2012
# 2    DILA inv  Gu2012  Gutiérrez_2012
# 3    DILA inv  Gu2012  Gutiérrez_2012
# 4    DILA inv  Gu2012  Gutiérrez_2012
#
#                                   Cita Bibliográfica       Consultante  \
# 0  Gutiérrez, Analía (2015). Segmental and prosod...   Elizabeth Rojas
# 1  Gutiérrez, Analía (2015). Segmental and prosod...  Graciano Ramírez
# 2  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 3  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 4  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
#
#                                   Original_audiopath  \
# 0  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 1  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 2  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 3  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 4  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
#
#                                         Recorte_path
# 0  /home/nidia/DILA/pict-glotales/assets/audio/20...
# 1  /home/nidia/DILA/pict-glotales/assets/audio/20...
# 2  /home/nidia/DILA/pict-glotales/assets/audio/20...
# 3  /home/nidia/DILA/pict-glotales/assets/audio/20...
# 4  /home/nidia/DILA/pict-glotales/assets/audio/20...

# %% [markdown]
# ‼️‼️‼️ Las columnas "Inicio (sg)" y "Fin (sg)" no tienen sentido para este corpus porque las elicitaciones son por palabra (esa info tiene sentido para buscarlas en archivos de elicitacioes más largas). ‼️‼️‼️

# %%
tcfil = pd.read_excel(f"{tcfildir}/TCFiladelfia.xlsx")
tcfil.head()
# Out:
#                      ID         AFI Transcripción_original    Glosa  \
# 0  2010_08_31_FR_AG_001       meʔeɬ                 meʼelh   cuando
# 1  2010_08_31_FR_AG_002         NaN                    NaN  oracion
# 2  2010_08_31_FR_AG_003        nɑʔɑ                   nôʼô      NaN
# 3  2010_08_31_FR_AG_004  nɑʔum nuʔu             nôʼum nuʼu      NaN
# 4  2010_08_31_FR_AG_005       peʔem                  peʼem      NaN
#
#                    Notas                                          Audiofile  \
# 0                    009  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 1                    NaN  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 2  no se usa mucho (oo10  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 3                    NaN  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 4                     12  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
#
#                                              Docfile
# 0  TCFiladelfiaAudios2010/2010_08_31FR/Tables31_8...
# 1  TCFiladelfiaAudios2010/2010_08_31FR/Tables31_8...
# 2  TCFiladelfiaAudios2010/2010_08_31FR/Tables31_8...
# 3  TCFiladelfiaAudios2010/2010_08_31FR/Tables31_8...
# 4  TCFiladelfiaAudios2010/2010_08_31FR/Tables31_8...

# %%
informantes = {
    'AC': 'Andres Crespo',
    'AJ': 'Agustín Juárez',
    'CS': 'Celestina Sacarías',
    'E': 'Ernestina',
    'ER': 'Elizabeth Rojas',
    'FR': 'Félix Ramírez',
    'FAR': 'Faustino Ramírez',
    'GR': 'Graciano Ramírez',
    'JR': 'José Rojas',
    'MV': 'Mauricio Valdez',
    'SD': 'Sofía Díaz', #'Chula'    
    'SR': 'Sara Rojas', #'Sara'
    'TS': 'Teresita Sánchez',
    'TeS': 'Teo Servín'
}

# %%
recortes_dir = '../pict-glotales/assets/audio'

new_rows = []

for _, row_sel in sel_niv.iterrows():
    for _, row_tcfil in tcfil.iterrows():
        if row_sel['Español'] == row_tcfil['Glosa']:
            
            #print(row_sel['Español'], row_tcfil['AFI'])
            
            row_sel['Palabra'] = row_tcfil['AFI']
            row_sel['ID Audio'] = row_tcfil['ID']
            row_sel['Código'] = f"Gu{row_tcfil['ID'].split('_')[0]}"
            row_sel['Cita Audio'] = f"Gutiérrez_{row_tcfil['ID'].split('_')[0]}"
            id_consultante = row_tcfil['ID'].split('_')[3]
            row_sel['Consultante'] = informantes[id_consultante]
            row_sel['Original_audiopath'] = row_tcfil['Audiofile']
            
            ## nombredelarchivofuenteresumido_glosaenespañol. Ej. 20120318_003_algarrobo
            nombre_recorte = row_tcfil['ID'].replace("_", "").replace("AG", "")+"_"+row_tcfil['Glosa'].replace(" ", "_")
            row_sel['Recorte_path'] = f"{recortes_dir}/{nombre_recorte}.wav"
            
        
#         ## Haya coincidencia o no, agrego la fila porque preservo las palabras para 
#         ## las que no se encontró nada en TCFiladeflia
        new_rows.append(row_sel)

# %%
df = pd.DataFrame(new_rows)
df = df.drop_duplicates()
df
# Out:
#              Español                                 Palabra  \
# 0               yica                                ɬk͡lasaʔ
# 1             iguana                                     aɬu
# 2           langosta                     fanxa fanxas fanxak
# 3         mi sobrino  jifak͡lʔa afak͡lʔa ɬfak͡lʔa kasfak͡lʔa
# 4         mi sobrina                              jifakt͡ʃḛ
# 5           mi panza                                jikaʔwot
# 6           mi oreja                                  jikfeʔ
# 7            mi mano          jipɑkɑt kaspɑkɑ̰t na watpɑkɑ̰t
# 8                vos              ɬatqaβʦak͡lajeʃ na neqxjɑk
# 9            ustedes        ɬatqaβʦak͡lajeɬ ɬatqaβʦak͡lajʃeɬ
# 10            sombra                                  ɬaχpek
# 11           cotorra                                  satʼas
# 12          nosotros                               ʃtaxṵxom
# 13              loro                                   ek͡le
# 14              luna                                     NaN
# 15              aire                                 βatajaɬ
# 16               sol                                     NaN
# 17            mi pie                                     NaN
# 18            paloma                                     NaN
# 19         algarrobo                                    fa̰j
# 20            gusano                                  tinwoʔ
# 21             tarde                                     NaN
# 22           mi hija                                     NaN
# 23              rata                                     NaN
# 24           mi cara                                     NaN
# 25           mi codo                                     NaN
# 26         mi cuello                                     NaN
# 27         mi diente                                     NaN
# 28            hombre                                     NaN
# 29              niño                                     NaN
# 30            mi ojo                                     NaN
# 31         brazalete                                     NaN
# 32             hacha                                     NaN
# 33         mi zapato                                     NaN
# 34  mi hermana menor                                     NaN
# 35  mi hermano menor                                     NaN
# 36          mi nieta                                     NaN
# 37             cielo                                     NaN
# 38             monte                                     NaN
# 39       quirquincho                                     NaN
# 40            mi tía                                     NaN
# 41                yo                                     NaN
# 42                él                                     NaN
# 43   espina de árbol                                     NaN
# 44          mi pecho                                     NaN
# 45           mi pelo                                     NaN
# 46          mi talón                                     NaN
# 47               red                                     NaN
# 48            camino                                     NaN
# 49           mi piel                                     NaN
# 50             carne                                     NaN
# 51         mi sangre                                     NaN
# 52        yo escucho                                     NaN
# 53             cuero                                     NaN
# 54              nube                                     NaN
# 55       mi costilla                                     NaN
# 56        mi corazon                                     NaN
# 57          mosquito                                     NaN
#
#                 ID Audio  Inicio (sg)  Fin (sg)   Lengua Transcriptorx  \
# 0   2011_07_08_ER_AG_125          NaN       NaN  nivacle            AG
# 1   2010_08_16_SR_AG_057          NaN       NaN  nivacle            AG
# 2   2012_03_13_FR_AG_140          NaN       NaN  nivacle            AG
# 3   2012_03_08_FR_AG_070          NaN       NaN  nivacle            AG
# 4   2012_03_08_FR_AG_069          NaN       NaN  nivacle            AG
# 5   2017_04_04_FR_AG_156          NaN       NaN  nivacle            AG
# 6   2010_07_04_FR_AG_044          NaN       NaN  nivacle            AG
# 7   2019_07_20_FR_AG_056          NaN       NaN  nivacle            AG
# 8   2011_07_12_FR_AG_065          NaN       NaN  nivacle            AG
# 9   2011_07_12_FR_AG_071          NaN       NaN  nivacle            AG
# 10  2012_05_05_FR_AG_063          NaN       NaN  nivacle            AG
# 11  2017_04_04_FR_AG_038          NaN       NaN  nivacle            AG
# 12  2011_07_12_FR_AG_049          NaN       NaN  nivacle            AG
# 13  2010_08_14_SR_AG_020          NaN       NaN  nivacle            AG
# 14  2010_08_24_FR_AG_211          NaN       NaN  nivacle            AG
# 15  2012_05_14_FR_AG_169          NaN       NaN  nivacle            AG
# 16  2010_08_24_FR_AG_210          NaN       NaN  nivacle            AG
# 17  2010_08_17_MV_AG_011          NaN       NaN  nivacle            AG
# 18  2010_08_14_AC_AG_011          NaN       NaN  nivacle            AG
# 19  2010_08_17_FR_AG_099          NaN       NaN  nivacle            AG
# 20  2010_08_31_FR_AG_077          NaN       NaN  nivacle            AG
# 21  2010_08_17_FR_AG_021          NaN       NaN  nivacle            AG
# 22                   NaN          NaN       NaN  nivacle            AG
# 23                   NaN          NaN       NaN  nivacle            AG
# 24                   NaN          NaN       NaN  nivacle            AG
# 25                   NaN          NaN       NaN  nivacle            AG
# 26                   NaN          NaN       NaN  nivacle            AG
# 27                   NaN          NaN       NaN  nivacle            AG
# 28                   NaN          NaN       NaN  nivacle            AG
# 29                   NaN          NaN       NaN  nivacle            AG
# 30                   NaN          NaN       NaN  nivacle            AG
# 31                   NaN          NaN       NaN  nivacle            AG
# 32                   NaN          NaN       NaN  nivacle            AG
# 33                   NaN          NaN       NaN  nivacle            AG
# 34                   NaN          NaN       NaN  nivacle            AG
# 35                   NaN          NaN       NaN  nivacle            AG
# 36                   NaN          NaN       NaN  nivacle            AG
# 37                   NaN          NaN       NaN  nivacle            AG
# 38                   NaN          NaN       NaN  nivacle            AG
# 39                   NaN          NaN       NaN  nivacle            AG
# 40                   NaN          NaN       NaN  nivacle            AG
# 41                   NaN          NaN       NaN  nivacle            AG
# 42                   NaN          NaN       NaN  nivacle            AG
# 43                   NaN          NaN       NaN  nivacle            AG
# 44                   NaN          NaN       NaN  nivacle            AG
# 45                   NaN          NaN       NaN  nivacle            AG
# 46                   NaN          NaN       NaN  nivacle            AG
# 47                   NaN          NaN       NaN  nivacle            AG
# 48                   NaN          NaN       NaN  nivacle            AG
# 49                   NaN          NaN       NaN  nivacle            AG
# 50                   NaN          NaN       NaN  nivacle            AG
# 51                   NaN          NaN       NaN  nivacle            AG
# 52                   NaN          NaN       NaN  nivacle            AG
# 53                   NaN          NaN       NaN  nivacle            AG
# 54                   NaN          NaN       NaN  nivacle            AG
# 55                   NaN          NaN       NaN  nivacle            AG
# 56                   NaN          NaN       NaN  nivacle            AG
# 57                   NaN          NaN       NaN  nivacle            AG
#
#    Herramienta    Tanda Repositorio  Código      Cita Audio  \
# 0         Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 1         Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 2         Word  2023-08    DILA inv  Gu2012  Gutiérrez_2012
# 3         Word  2023-08    DILA inv  Gu2012  Gutiérrez_2012
# 4         Word  2023-08    DILA inv  Gu2012  Gutiérrez_2012
# 5         Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 6         Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 7         Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 8         Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 9         Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 10        Word  2023-08    DILA inv  Gu2012  Gutiérrez_2012
# 11        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 12        Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 13        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 14        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 15        Word  2023-08    DILA inv  Gu2012  Gutiérrez_2012
# 16        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 17        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 18        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 19        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 20        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 21        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 22        Word  2023-08    DILA inv  Gu2012             NaN
# 23        Word  2023-08    DILA inv  Gu2012             NaN
# 24        Word  2023-08    DILA inv  Gu2012             NaN
# 25        Word  2023-08    DILA inv  Gu2012             NaN
# 26        Word  2023-08    DILA inv  Gu2012             NaN
# 27        Word  2023-08    DILA inv  Gu2012             NaN
# 28        Word  2023-08    DILA inv  Gu2012             NaN
# 29        Word  2023-08    DILA inv  Gu2012             NaN
# 30        Word  2023-08    DILA inv  Gu2012             NaN
# 31        Word  2023-08    DILA inv  Gu2012             NaN
# 32        Word  2023-08    DILA inv  Gu2012             NaN
# 33        Word  2023-08    DILA inv  Gu2012             NaN
# 34        Word  2023-08    DILA inv  Gu2012             NaN
# 35        Word  2023-08    DILA inv  Gu2012             NaN
# 36        Word  2023-08    DILA inv  Gu2012             NaN
# 37        Word  2023-08    DILA inv  Gu2012             NaN
# 38        Word  2023-08    DILA inv  Gu2012             NaN
# 39        Word  2023-08    DILA inv  Gu2012             NaN
# 40        Word  2023-08    DILA inv  Gu2012             NaN
# 41        Word  2023-08    DILA inv  Gu2012             NaN
# 42        Word  2023-08    DILA inv  Gu2012             NaN
# 43        Word  2023-08    DILA inv  Gu2012             NaN
# 44        Word  2023-08    DILA inv  Gu2012             NaN
# 45        Word  2023-08    DILA inv  Gu2012             NaN
# 46        Word  2023-08    DILA inv  Gu2012             NaN
# 47        Word  2023-08    DILA inv  Gu2012             NaN
# 48        Word  2023-08    DILA inv  Gu2012             NaN
# 49        Word  2023-08    DILA inv  Gu2012             NaN
# 50        Word  2023-08    DILA inv  Gu2012             NaN
# 51        Word  2023-08    DILA inv  Gu2012             NaN
# 52        Word  2023-08    DILA inv  Gu2012             NaN
# 53        Word  2023-08    DILA inv  Gu2012             NaN
# 54        Word  2023-08    DILA inv  Gu2012             NaN
# 55        Word  2023-08    DILA inv  Gu2012             NaN
# 56        Word  2023-08    DILA inv  Gu2012             NaN
# 57        Word  2023-08    DILA inv  Gu2012             NaN
#
#                                    Cita Bibliográfica      Consultante  \
# 0   Gutiérrez, Analía (2015). Segmental and prosod...  Elizabeth Rojas
# 1   Gutiérrez, Analía (2015). Segmental and prosod...       Sara Rojas
# 2   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 3   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 4   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 5   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 6   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 7   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 8   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 9   Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 10  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 11  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 12  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 13  Gutiérrez, Analía (2015). Segmental and prosod...       Sara Rojas
# 14  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 15  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 16  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 17  Gutiérrez, Analía (2015). Segmental and prosod...  Mauricio Valdez
# 18  Gutiérrez, Analía (2015). Segmental and prosod...    Andres Crespo
# 19  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 20  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 21  Gutiérrez, Analía (2015). Segmental and prosod...    Félix Ramírez
# 22  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 23  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 24  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 25  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 26  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 27  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 28  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 29  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 30  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 31  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 32  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 33  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 34  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 35  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 36  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 37  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 38  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 39  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 40  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 41  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 42  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 43  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 44  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 45  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 46  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 47  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 48  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 49  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 50  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 51  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 52  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 53  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 54  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 55  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 56  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
# 57  Gutiérrez, Analía (2015). Segmental and prosod...              NaN
#
#                                    Original_audiopath  \
# 0   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 1   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 2   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 3   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 4   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 5   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 6   DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 11  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 12                                                NaN
# 13  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 14  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 15  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 16  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 17  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 18  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 19  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 20  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 21  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
#
#                                          Recorte_path
# 0   ../pict-glotales/assets/audio/20110708ER125_yi...
# 1   ../pict-glotales/assets/audio/20100816SR057_ig...
# 2   ../pict-glotales/assets/audio/20120313FR140_la...
# 3   ../pict-glotales/assets/audio/20120308FR070_mi...
# 4   ../pict-glotales/assets/audio/20120308FR069_mi...
# 5   ../pict-glotales/assets/audio/20170404FR156_mi...
# 6   ../pict-glotales/assets/audio/20100704FR044_mi...
# 7   ../pict-glotales/assets/audio/20190720FR056_mi...
# 8   ../pict-glotales/assets/audio/20110712FR065_vo...
# 9   ../pict-glotales/assets/audio/20110712FR071_us...
# 10  ../pict-glotales/assets/audio/20120505FR063_so...
# 11  ../pict-glotales/assets/audio/20170404FR038_co...
# 12  ../pict-glotales/assets/audio/20110712FR049_no...
# 13  ../pict-glotales/assets/audio/20100814SR020_lo...
# 14  ../pict-glotales/assets/audio/20100824FR211_lu...
# 15  ../pict-glotales/assets/audio/20120514FR169_ai...
# 16  ../pict-glotales/assets/audio/20100824FR210_so...
# 17  ../pict-glotales/assets/audio/20100817MV011_mi...
# 18  ../pict-glotales/assets/audio/20100814AC011_pa...
# 19  ../pict-glotales/assets/audio/20100817FR099_al...
# 20  ../pict-glotales/assets/audio/20100831FR077_gu...
# 21  ../pict-glotales/assets/audio/20100817FR021_ta...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN

# %%
df['Herramienta'] = 'Word'

# %%
df.shape

# %% [markdown]
# Agrego a mano un original audiopath que falta en el df de tcfiladelfia:

# %%
df.iat[7,14] = "DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaAudios2019/20190720FR/20190720_FR_AG_056.wav"

# %%
df.to_csv("seleccion-recortes-audio-nivacle-ago-2023.csv", index = False)

# %% [markdown]
# ⚠️⚠️⚠️
#
# ESTOS SON LOS CASOS SIN MATCH QUE HAY QUE REVISAR!!
#
# ⚠️⚠️⚠️

# %%
df = pd.read_csv("seleccion-recortes-audio-nivacle-ago-2023.csv")
df = df[
    ( df['Palabra'].isnull() ) & 
    ( df['ID Audio'].isnull() )
]
df
# Out:
#              Español Palabra ID Audio  Inicio (sg)  Fin (sg)   Lengua  \
# 22           mi hija     NaN      NaN          NaN       NaN  nivacle
# 23              rata     NaN      NaN          NaN       NaN  nivacle
# 24           mi cara     NaN      NaN          NaN       NaN  nivacle
# 25           mi codo     NaN      NaN          NaN       NaN  nivacle
# 26         mi cuello     NaN      NaN          NaN       NaN  nivacle
# 27         mi diente     NaN      NaN          NaN       NaN  nivacle
# 28            hombre     NaN      NaN          NaN       NaN  nivacle
# 29              niño     NaN      NaN          NaN       NaN  nivacle
# 30            mi ojo     NaN      NaN          NaN       NaN  nivacle
# 31         brazalete     NaN      NaN          NaN       NaN  nivacle
# 32             hacha     NaN      NaN          NaN       NaN  nivacle
# 33         mi zapato     NaN      NaN          NaN       NaN  nivacle
# 34  mi hermana menor     NaN      NaN          NaN       NaN  nivacle
# 35  mi hermano menor     NaN      NaN          NaN       NaN  nivacle
# 36          mi nieta     NaN      NaN          NaN       NaN  nivacle
# 37             cielo     NaN      NaN          NaN       NaN  nivacle
# 38             monte     NaN      NaN          NaN       NaN  nivacle
# 39       quirquincho     NaN      NaN          NaN       NaN  nivacle
# 40            mi tía     NaN      NaN          NaN       NaN  nivacle
# 41                yo     NaN      NaN          NaN       NaN  nivacle
# 42               él      NaN      NaN          NaN       NaN  nivacle
# 43   espina de árbol     NaN      NaN          NaN       NaN  nivacle
# 44          mi pecho     NaN      NaN          NaN       NaN  nivacle
# 45           mi pelo     NaN      NaN          NaN       NaN  nivacle
# 46          mi talón     NaN      NaN          NaN       NaN  nivacle
# 47               red     NaN      NaN          NaN       NaN  nivacle
# 48            camino     NaN      NaN          NaN       NaN  nivacle
# 49           mi piel     NaN      NaN          NaN       NaN  nivacle
# 50             carne     NaN      NaN          NaN       NaN  nivacle
# 51         mi sangre     NaN      NaN          NaN       NaN  nivacle
# 52        yo escucho     NaN      NaN          NaN       NaN  nivacle
# 53             cuero     NaN      NaN          NaN       NaN  nivacle
# 54              nube     NaN      NaN          NaN       NaN  nivacle
# 55       mi costilla     NaN      NaN          NaN       NaN  nivacle
# 56        mi corazon     NaN      NaN          NaN       NaN  nivacle
# 57          mosquito     NaN      NaN          NaN       NaN  nivacle
#
#    Transcriptorx Herramienta    Tanda Repositorio  Código Cita Audio  \
# 22            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 23            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 24            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 25            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 26            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 27            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 28            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 29            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 30            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 31            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 32            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 33            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 34            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 35            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 36            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 37            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 38            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 39            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 40            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 41            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 42            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 43            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 44            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 45            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 46            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 47            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 48            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 49            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 50            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 51            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 52            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 53            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 54            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 55            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 56            AG        Word  2023-08    DILA inv  Gu2012        NaN
# 57            AG        Word  2023-08    DILA inv  Gu2012        NaN
#
#                                    Cita Bibliográfica Consultante  \
# 22  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 23  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 24  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 25  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 26  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 27  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 28  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 29  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 30  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 31  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 32  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 33  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 34  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 35  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 36  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 37  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 38  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 39  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 40  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 41  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 42  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 43  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 44  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 45  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 46  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 47  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 48  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 49  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 50  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 51  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 52  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 53  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 54  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 55  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 56  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
# 57  Gutiérrez, Analía (2015). Segmental and prosod...         NaN
#
#    Original_audiopath Recorte_path
# 22                NaN          NaN
# 23                NaN          NaN
# 24                NaN          NaN
# 25                NaN          NaN
# 26                NaN          NaN
# 27                NaN          NaN
# 28                NaN          NaN
# 29                NaN          NaN
# 30                NaN          NaN
# 31                NaN          NaN
# 32                NaN          NaN
# 33                NaN          NaN
# 34                NaN          NaN
# 35                NaN          NaN
# 36                NaN          NaN
# 37                NaN          NaN
# 38                NaN          NaN
# 39                NaN          NaN
# 40                NaN          NaN
# 41                NaN          NaN
# 42                NaN          NaN
# 43                NaN          NaN
# 44                NaN          NaN
# 45                NaN          NaN
# 46                NaN          NaN
# 47                NaN          NaN
# 48                NaN          NaN
# 49                NaN          NaN
# 50                NaN          NaN
# 51                NaN          NaN
# 52                NaN          NaN
# 53                NaN          NaN
# 54                NaN          NaN
# 55                NaN          NaN
# 56                NaN          NaN
# 57                NaN          NaN

# %% [markdown]
# Si no hay glosa en el df de TCFiladelfia no tenemos con qué comparar así que descartamos las filas con glosa faltante:

# %%
recortes_dir = '../pict-glotales/assets/audio'

rows = []

for _, row_sel in df.iterrows():
    for _, row_tcfil in tcfil.dropna(subset=["Glosa"]).iterrows():
        if row_sel['Español'] in row_tcfil['Glosa']:
            #print(f"{row_sel['Español']} || {row_tcfil['Glosa']} || {row_tcfil['AFI']}")
            
            row_sel['Palabra'] = row_tcfil['AFI']
            
            #########
            row_sel['GlosaEnTCFil'] = row_tcfil['Glosa'] ## para controlar, BORRAR
            #########
            
            row_sel['ID Audio'] = row_tcfil['ID']
            row_sel['Código'] = f"Gu{row_tcfil['ID'].split('_')[0]}"
            row_sel['Cita Audio'] = f"Gutiérrez_{row_tcfil['ID'].split('_')[0]}"
            id_consultante = row_tcfil['ID'].split('_')[3]
            row_sel['Consultante'] = informantes[id_consultante]
            row_sel['Original_audiopath'] = row_tcfil['Audiofile']
            
            ## nombredelarchivofuenteresumido_glosaenespañol. Ej. 20120318_003_algarrobo
            nombre_recorte = row_tcfil['ID'].replace("_", "").replace("AG", "")+"_"+row_tcfil['Glosa'].replace(" ", "_")
            row_sel['Recorte_path'] = f"{recortes_dir}/{nombre_recorte}.wav"
            
            #########
            ##print(f"{row_sel['Español']} || {row_sel['Palabra']} |||| {row_tcfil['Glosa']} || {row_tcfil['AFI']}")
            rows.append(row_sel) ### POR QUÉ SÓLO HACE APPEND DEL ÚLTIMO MATCH EN row_sel SI LO DE ARRIBA SE VE BIEN???
            #########

# %%
rows[0:3]
# Out:
# [Español                                                         mi hija
#  Palabra               k͡lop k͡lop na jɑ̰s ɬa jɑse k͡lim k͡lop k͡lop ...
#  ID Audio                                          2019_07_23_TeS_AG_025
#  Inicio (sg)                                                         NaN
#  Fin (sg)                                                            NaN
#  Lengua                                                          nivacle
#  Transcriptorx                                                        AG
#  Herramienta                                                        Word
#  Tanda                                                           2023-08
#  Repositorio                                                    DILA inv
#  Código                                                           Gu2019
#  Cita Audio                                               Gutiérrez_2019
#  Cita Bibliográfica    Gutiérrez, Analía (2015). Segmental and prosod...
#  Consultante                                                  Teo Servín
#  Original_audiopath                                                  NaN
#  Recorte_path          ../pict-glotales/assets/audio/20190723TeS025_b...
#  GlosaEnTCFil          blanco mi hijo es blanca mi hija es blanca es ...
#  Name: 22, dtype: object,
#  Español                                                         mi hija
#  Palabra               k͡lop k͡lop na jɑ̰s ɬa jɑse k͡lim k͡lop k͡lop ...
#  ID Audio                                          2019_07_23_TeS_AG_025
#  Inicio (sg)                                                         NaN
#  Fin (sg)                                                            NaN
#  Lengua                                                          nivacle
#  Transcriptorx                                                        AG
#  Herramienta                                                        Word
#  Tanda                                                           2023-08
#  Repositorio                                                    DILA inv
#  Código                                                           Gu2019
#  Cita Audio                                               Gutiérrez_2019
#  Cita Bibliográfica    Gutiérrez, Analía (2015). Segmental and prosod...
#  Consultante                                                  Teo Servín
#  Original_audiopath                                                  NaN
#  Recorte_path          ../pict-glotales/assets/audio/20190723TeS025_b...
#  GlosaEnTCFil          blanco mi hijo es blanca mi hija es blanca es ...
#  Name: 22, dtype: object,
#  Español                                                         mi hija
#  Palabra               k͡lop k͡lop na jɑ̰s ɬa jɑse k͡lim k͡lop k͡lop ...
#  ID Audio                                          2019_07_23_TeS_AG_025
#  Inicio (sg)                                                         NaN
#  Fin (sg)                                                            NaN
#  Lengua                                                          nivacle
#  Transcriptorx                                                        AG
#  Herramienta                                                        Word
#  Tanda                                                           2023-08
#  Repositorio                                                    DILA inv
#  Código                                                           Gu2019
#  Cita Audio                                               Gutiérrez_2019
#  Cita Bibliográfica    Gutiérrez, Analía (2015). Segmental and prosod...
#  Consultante                                                  Teo Servín
#  Original_audiopath                                                  NaN
#  Recorte_path          ../pict-glotales/assets/audio/20190723TeS025_b...
#  GlosaEnTCFil          blanco mi hijo es blanca mi hija es blanca es ...
#  Name: 22, dtype: object]

# %%
df3 = pd.DataFrame(new_rows2)
df3 = df3.drop_duplicates()
df3
# Out:
#         Español                                            Palabra  \
# 22      mi hija  k͡lop k͡lop na jɑ̰s ɬa jɑse k͡lim k͡lop k͡lop ...
# 23         rata  ɑmpa ɑmpa ka na̰ʔan ɑmʔɑ ɬa ɑmʔɑ ux ti kʼuʦxan...
# 27    mi diente                      xanɑmatʼe ɬka jiʦewte nɑmatʼe
# 28       hombre  tkamk͡loj tkamk͡lojʔin xa niwak͡le tkamkɑj tka...
# 29         niño  \tjɑ̰jʃekɑtʼin\t xɑʔkiɬaj kɑkiɬaj kʼajɑ̰j xa j...
# 30       mi ojo                  tɑseχ ɬa ji tɑseχ ux ux ɬajitɑseχ
# 32        hacha                             anamaʧ niʧʼa na anamaʧ
# 37        cielo  niʔjiʔwan xaɬek͡loxeʃ ti ka̰x xaju pa empanada...
# 38        monte                                                NaN
# 40       mi tía                       teja teja ɬxa itɑx ti jitʼeʃ
# 41           yo  fa fanxa sa sas ʃa ʃaɬa̰ ɬa ɬawijm xa xosɑx xa...
# 42          él                    naʧan naʧan ɬɑn xɑʔkḛj ɬa ɬuʦxa
# 45      mi pelo  ux pa jisaʃ jisaʃ jikasaʃ na jisa̰ʃ xa nuxumaʦ...
# 47          red                                                NaN
# 48       camino   nɑjiʃ fkʼaʦaxʧʼe na nɑjiʃ xawa nɑjʃaj fkʼaʦasʧʼe
# 50        carne  jisxa̰n jiʔwṵn jiwutun jiwutun na xpɑjiʧ jiwu...
# 51    mi sangre             jiʔwojej jiwoʔjej ʃtanwojej na watataʃ
# 53        cuero  nɑke naɬu ta̰x taxʔin nitaxaʦuʔin ta̰xtaxʔin t...
# 54         nube          ʃinwanxuɬ na niwak͡le jiwanxuɬ nawa wosej
# 55  mi costilla                         jiwɬiʔ wata̰wɬis wata̰wɬiʔ
# 56   mi corazon        ɬḭβte jiɬḭβte aɬḭβte kasɬḭβte βatɬḭβte
# 57     mosquito                              jijaʔ ʦixṵx ɬa jijaʔ
#
#                  ID Audio  Inicio (sg)  Fin (sg)   Lengua Transcriptorx  \
# 22  2019_07_23_TeS_AG_025          NaN       NaN  nivacle            AG
# 23  2019_07_23_TeS_AG_043          NaN       NaN  nivacle            AG
# 27   2017_07_10_FR_AG_032          NaN       NaN  nivacle            AG
# 28  2019_07_23_TeS_AG_048          NaN       NaN  nivacle            AG
# 29   2019_07_20_FR_AG_063          NaN       NaN  nivacle            AG
# 30   2010_07_04_FR_AG_059          NaN       NaN  nivacle            AG
# 32   2017_07_10_FR_AG_033          NaN       NaN  nivacle            AG
# 37   2017_07_07_FR_AG_036          NaN       NaN  nivacle            AG
# 38  2019_07_22_TeS_AG_012          NaN       NaN  nivacle            AG
# 40   2017_04_08_TS_AG_017          NaN       NaN  nivacle            AG
# 41  2019_07_23_TeS_AG_041          NaN       NaN  nivacle            AG
# 42  2019_07_23_TeS_AG_006          NaN       NaN  nivacle            AG
# 45  2019_07_23_TeS_AG_022          NaN       NaN  nivacle            AG
# 47  2019_07_22_TeS_AG_002          NaN       NaN  nivacle            AG
# 48   2019_07_20_FR_AG_040          NaN       NaN  nivacle            AG
# 50   2017_07_08_TS_AG_053          NaN       NaN  nivacle            AG
# 51   2019_07_20_FR_AG_046          NaN       NaN  nivacle            AG
# 53  2019_07_23_TeS_AG_045          NaN       NaN  nivacle            AG
# 54   2019_07_20_FR_AG_034          NaN       NaN  nivacle            AG
# 55   2019_07_20_FR_AG_062          NaN       NaN  nivacle            AG
# 56   2011_07_12_FR_AG_076          NaN       NaN  nivacle            AG
# 57  2019_07_23_TeS_AG_030          NaN       NaN  nivacle            AG
#
#    Herramienta    Tanda Repositorio  Código      Cita Audio  \
# 22        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 23        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 27        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 28        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 29        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 30        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 32        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 37        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 38        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 40        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 41        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 42        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 45        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 47        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 48        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 50        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 51        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 53        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 54        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 55        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 56        Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 57        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
#
#                                    Cita Bibliográfica       Consultante  \
# 22  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 23  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 27  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 28  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 29  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 30  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 32  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 37  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 38  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 40  Gutiérrez, Analía (2015). Segmental and prosod...  Teresita Sánchez
# 41  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 42  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 45  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 47  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 48  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 50  Gutiérrez, Analía (2015). Segmental and prosod...  Teresita Sánchez
# 51  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 53  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 54  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 55  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 56  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 57  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
#
#                                    Original_audiopath  \
# 22                                                NaN
# 23                                                NaN
# 27  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 28                                                NaN
# 29                                                NaN
# 30  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 32  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 37  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 38                                                NaN
# 40  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 41                                                NaN
# 42                                                NaN
# 45                                                NaN
# 47                                                NaN
# 48                                                NaN
# 50  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 51                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
#
#                                          Recorte_path  \
# 22  ../pict-glotales/assets/audio/20190723TeS025_b...
# 23  ../pict-glotales/assets/audio/20190723TeS043_n...
# 27  ../pict-glotales/assets/audio/20170710FR032_ar...
# 28  ../pict-glotales/assets/audio/20190723TeS048_e...
# 29  ../pict-glotales/assets/audio/20190720FR063_no...
# 30  ../pict-glotales/assets/audio/20100704FR059_oj...
# 32  ../pict-glotales/assets/audio/20170710FR033_tu...
# 37  ../pict-glotales/assets/audio/20170707FR036_no...
# 38  ../pict-glotales/assets/audio/20190722TeS012_l...
# 40  ../pict-glotales/assets/audio/20170408TS017_po...
# 41  ../pict-glotales/assets/audio/20190723TeS041__...
# 42  ../pict-glotales/assets/audio/20190723TeS006_s...
# 45  ../pict-glotales/assets/audio/20190723TeS022_t...
# 47  ../pict-glotales/assets/audio/20190722TeS002_e...
# 48  ../pict-glotales/assets/audio/20190720FR040_ca...
# 50  ../pict-glotales/assets/audio/20170708TS053_mi...
# 51  ../pict-glotales/assets/audio/20190720FR046_mi...
# 53  ../pict-glotales/assets/audio/20190723TeS045_e...
# 54  ../pict-glotales/assets/audio/20190720FR034_no...
# 55  ../pict-glotales/assets/audio/20190720FR062_mi...
# 56  ../pict-glotales/assets/audio/20110712FR076_co...
# 57  ../pict-glotales/assets/audio/20190723TeS030_m...
#
#                                          GlosaEnTCFil
# 22  blanco mi hijo es blanca mi hija es blanca es ...
# 23  nada no hay nada/no pasa nada la rata es robadora
# 27                                  arranco mi diente
# 28  el hombre es violento las mujeres tienen su mo...
# 29  nombre de Félix nombre de Faustino niños multi...
# 30                              ojo. mi ojo es grande
# 32                         tu hacha es nueva tu hacha
# 37  no veo imagino que va a haber empanada/comida....
# 38  lame la sal ellos son dos ceniza ceniza del mo...
# 40                      porque porque mi tía dijo que
# 41           langosta feo cerca viento arena yo corro
# 42    se esfuerza/ansia él tenía interés en esa chica
# 45  tengo mucha mucosidad mi flema mi lana yo mant...
# 47  este nivacle (conocés y ves) dónde está el niv...
# 48  camino el camino es amplio los caminos son amp...
# 50  mi carne mi carne de pescado se quema se quema...
# 51  mi sangre a tiempo llegó llegamos a tiempo a l...
# 53  este día llueve está lloviendo está por llover...
# 54  nos ve, cuando nos íbamos el nivacle ve las nu...
# 55                   mi costilla costillas de alguien
# 56  corazon mi corazon tu corazon nuestro corazon ...
# 57                       mosquito me pica el mosquito

# %%
new_rows2[0]
# Out:
# 'rata || una planta chiquitita medicinal amarilla, se usa para tratar hongos || ʃek͡lox'

# %%
df2
# Out:
#              Español                                            Palabra  \
# 22           mi hija  k͡lop k͡lop na jɑ̰s ɬa jɑse k͡lim k͡lop k͡lop ...
# 23              rata  ɑmpa ɑmpa ka na̰ʔan ɑmʔɑ ɬa ɑmʔɑ ux ti kʼuʦxan...
# 24           mi cara                                                NaN
# 25           mi codo                                                NaN
# 26         mi cuello                                                NaN
# 27         mi diente                      xanɑmatʼe ɬka jiʦewte nɑmatʼe
# 28            hombre  tkamk͡loj tkamk͡lojʔin xa niwak͡le tkamkɑj tka...
# 29              niño  \tjɑ̰jʃekɑtʼin\t xɑʔkiɬaj kɑkiɬaj kʼajɑ̰j xa j...
# 30            mi ojo                  tɑseχ ɬa ji tɑseχ ux ux ɬajitɑseχ
# 31         brazalete                                                NaN
# 32             hacha                             anamaʧ niʧʼa na anamaʧ
# 33         mi zapato                                                NaN
# 34  mi hermana menor                                                NaN
# 35  mi hermano menor                                                NaN
# 36          mi nieta                                                NaN
# 37             cielo  niʔjiʔwan xaɬek͡loxeʃ ti ka̰x xaju pa empanada...
# 38             monte                                                NaN
# 39       quirquincho                                                NaN
# 40            mi tía                       teja teja ɬxa itɑx ti jitʼeʃ
# 41                yo  fa fanxa sa sas ʃa ʃaɬa̰ ɬa ɬawijm xa xosɑx xa...
# 42               él                    naʧan naʧan ɬɑn xɑʔkḛj ɬa ɬuʦxa
# 43   espina de árbol                                                NaN
# 44          mi pecho                                                NaN
# 45           mi pelo  ux pa jisaʃ jisaʃ jikasaʃ na jisa̰ʃ xa nuxumaʦ...
# 46          mi talón                                                NaN
# 47               red                                                NaN
# 48            camino   nɑjiʃ fkʼaʦaxʧʼe na nɑjiʃ xawa nɑjʃaj fkʼaʦasʧʼe
# 49           mi piel                                                NaN
# 50             carne  jisxa̰n jiʔwṵn jiwutun jiwutun na xpɑjiʧ jiwu...
# 51         mi sangre             jiʔwojej jiwoʔjej ʃtanwojej na watataʃ
# 52        yo escucho                                                NaN
# 53             cuero  nɑke naɬu ta̰x taxʔin nitaxaʦuʔin ta̰xtaxʔin t...
# 54              nube          ʃinwanxuɬ na niwak͡le jiwanxuɬ nawa wosej
# 55       mi costilla                         jiwɬiʔ wata̰wɬis wata̰wɬiʔ
# 56        mi corazon        ɬḭβte jiɬḭβte aɬḭβte kasɬḭβte βatɬḭβte
# 57          mosquito                              jijaʔ ʦixṵx ɬa jijaʔ
#
#                  ID Audio  Inicio (sg)  Fin (sg)   Lengua Transcriptorx  \
# 22  2019_07_23_TeS_AG_025          NaN       NaN  nivacle            AG
# 23  2019_07_23_TeS_AG_043          NaN       NaN  nivacle            AG
# 24                    NaN          NaN       NaN  nivacle            AG
# 25                    NaN          NaN       NaN  nivacle            AG
# 26                    NaN          NaN       NaN  nivacle            AG
# 27   2017_07_10_FR_AG_032          NaN       NaN  nivacle            AG
# 28  2019_07_23_TeS_AG_048          NaN       NaN  nivacle            AG
# 29   2019_07_20_FR_AG_063          NaN       NaN  nivacle            AG
# 30   2010_07_04_FR_AG_059          NaN       NaN  nivacle            AG
# 31                    NaN          NaN       NaN  nivacle            AG
# 32   2017_07_10_FR_AG_033          NaN       NaN  nivacle            AG
# 33                    NaN          NaN       NaN  nivacle            AG
# 34                    NaN          NaN       NaN  nivacle            AG
# 35                    NaN          NaN       NaN  nivacle            AG
# 36                    NaN          NaN       NaN  nivacle            AG
# 37   2017_07_07_FR_AG_036          NaN       NaN  nivacle            AG
# 38  2019_07_22_TeS_AG_012          NaN       NaN  nivacle            AG
# 39                    NaN          NaN       NaN  nivacle            AG
# 40   2017_04_08_TS_AG_017          NaN       NaN  nivacle            AG
# 41  2019_07_23_TeS_AG_041          NaN       NaN  nivacle            AG
# 42  2019_07_23_TeS_AG_006          NaN       NaN  nivacle            AG
# 43                    NaN          NaN       NaN  nivacle            AG
# 44                    NaN          NaN       NaN  nivacle            AG
# 45  2019_07_23_TeS_AG_022          NaN       NaN  nivacle            AG
# 46                    NaN          NaN       NaN  nivacle            AG
# 47  2019_07_22_TeS_AG_002          NaN       NaN  nivacle            AG
# 48   2019_07_20_FR_AG_040          NaN       NaN  nivacle            AG
# 49                    NaN          NaN       NaN  nivacle            AG
# 50   2017_07_08_TS_AG_053          NaN       NaN  nivacle            AG
# 51   2019_07_20_FR_AG_046          NaN       NaN  nivacle            AG
# 52                    NaN          NaN       NaN  nivacle            AG
# 53  2019_07_23_TeS_AG_045          NaN       NaN  nivacle            AG
# 54   2019_07_20_FR_AG_034          NaN       NaN  nivacle            AG
# 55   2019_07_20_FR_AG_062          NaN       NaN  nivacle            AG
# 56   2011_07_12_FR_AG_076          NaN       NaN  nivacle            AG
# 57  2019_07_23_TeS_AG_030          NaN       NaN  nivacle            AG
#
#    Herramienta    Tanda Repositorio  Código      Cita Audio  \
# 22        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 23        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 24        Word  2023-08    DILA inv  Gu2012             NaN
# 25        Word  2023-08    DILA inv  Gu2012             NaN
# 26        Word  2023-08    DILA inv  Gu2012             NaN
# 27        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 28        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 29        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 30        Word  2023-08    DILA inv  Gu2010  Gutiérrez_2010
# 31        Word  2023-08    DILA inv  Gu2012             NaN
# 32        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 33        Word  2023-08    DILA inv  Gu2012             NaN
# 34        Word  2023-08    DILA inv  Gu2012             NaN
# 35        Word  2023-08    DILA inv  Gu2012             NaN
# 36        Word  2023-08    DILA inv  Gu2012             NaN
# 37        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 38        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 39        Word  2023-08    DILA inv  Gu2012             NaN
# 40        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 41        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 42        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 43        Word  2023-08    DILA inv  Gu2012             NaN
# 44        Word  2023-08    DILA inv  Gu2012             NaN
# 45        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 46        Word  2023-08    DILA inv  Gu2012             NaN
# 47        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 48        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 49        Word  2023-08    DILA inv  Gu2012             NaN
# 50        Word  2023-08    DILA inv  Gu2017  Gutiérrez_2017
# 51        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 52        Word  2023-08    DILA inv  Gu2012             NaN
# 53        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 54        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 55        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
# 56        Word  2023-08    DILA inv  Gu2011  Gutiérrez_2011
# 57        Word  2023-08    DILA inv  Gu2019  Gutiérrez_2019
#
#                                    Cita Bibliográfica       Consultante  \
# 22  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 23  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 24  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 25  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 26  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 27  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 28  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 29  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 30  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 31  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 32  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 33  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 34  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 35  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 36  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 37  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 38  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 39  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 40  Gutiérrez, Analía (2015). Segmental and prosod...  Teresita Sánchez
# 41  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 42  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 43  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 44  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 45  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 46  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 47  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 48  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 49  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 50  Gutiérrez, Analía (2015). Segmental and prosod...  Teresita Sánchez
# 51  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 52  Gutiérrez, Analía (2015). Segmental and prosod...               NaN
# 53  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
# 54  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 55  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 56  Gutiérrez, Analía (2015). Segmental and prosod...     Félix Ramírez
# 57  Gutiérrez, Analía (2015). Segmental and prosod...        Teo Servín
#
#                                    Original_audiopath  \
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 28                                                NaN
# 29                                                NaN
# 30  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 31                                                NaN
# 32  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 38                                                NaN
# 39                                                NaN
# 40  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
#
#                                          Recorte_path
# 22  ../pict-glotales/assets/audio/20190723TeS025_b...
# 23  ../pict-glotales/assets/audio/20190723TeS043_n...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  ../pict-glotales/assets/audio/20170710FR032_ar...
# 28  ../pict-glotales/assets/audio/20190723TeS048_e...
# 29  ../pict-glotales/assets/audio/20190720FR063_no...
# 30  ../pict-glotales/assets/audio/20100704FR059_oj...
# 31                                                NaN
# 32  ../pict-glotales/assets/audio/20170710FR033_tu...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  ../pict-glotales/assets/audio/20170707FR036_no...
# 38  ../pict-glotales/assets/audio/20190722TeS012_l...
# 39                                                NaN
# 40  ../pict-glotales/assets/audio/20170408TS017_po...
# 41  ../pict-glotales/assets/audio/20190723TeS041__...
# 42  ../pict-glotales/assets/audio/20190723TeS006_s...
# 43                                                NaN
# 44                                                NaN
# 45  ../pict-glotales/assets/audio/20190723TeS022_t...
# 46                                                NaN
# 47  ../pict-glotales/assets/audio/20190722TeS002_e...
# 48  ../pict-glotales/assets/audio/20190720FR040_ca...
# 49                                                NaN
# 50  ../pict-glotales/assets/audio/20170708TS053_mi...
# 51  ../pict-glotales/assets/audio/20190720FR046_mi...
# 52                                                NaN
# 53  ../pict-glotales/assets/audio/20190723TeS045_e...
# 54  ../pict-glotales/assets/audio/20190720FR034_no...
# 55  ../pict-glotales/assets/audio/20190720FR062_mi...
# 56  ../pict-glotales/assets/audio/20110712FR076_co...
# 57  ../pict-glotales/assets/audio/20190723TeS030_m...

# %%
for _, row_sel in sel_niv.iterrows():
    expr = re.compile(row_sel['Español'])
    for _, row_tcfil in tcfil.iterrows():
        if re.search(expr, row_tcfil['Glosa']):
            print(row_sel['Español'], row_tcfil['Glosa'])

# %% [markdown]
# ## 2. Hacer recortes de audio para las palabras encontradas

# %% [markdown]
# Hay muchas palabras para las que no hubo match entre la glosa pedida por AG y la glosa en TCFiladelfia.
#
# A continuación, casos en los que sí hubo match.
#
# 🆗🆗🆗 Primero, casos con glosa y con Id de audio:

# %%
info_ok = df.dropna(subset=["Palabra", "ID Audio"])
df.dropna(subset=["Palabra", "ID Audio"]) ## Casos para los que sí hay info, o bien en "Glosa" o bien en "ID Audio"

# %% [markdown]
#  🆗🆗🆗 Casos en los que no hay glosa pero sí hay audio (sirven porque AG los puede glosar).

# %%
audio_sin_glosa = df[(df['Palabra'].isnull() ) & (~df['ID Audio'].isnull())]
audio_sin_glosa

# %%
print(f'Hubo {len(info_ok)} donde encontramos bien la info')
print(f'Hubo {len(audio_sin_glosa)} casos de palabras sin glosa pero con audio')
print(f'Podemos hacer recortes de {len(info_ok) + len(audio_sin_glosa)} palabras')

# %%
con_data = pd.concat([info_ok, audio_sin_glosa])
con_data

# %%
#import shutil

for _, row in con_data.iterrows():
    src_path = f"/home/nidia/{row['Original_audiopath']}"
    dst_path = row['Recorte_path']
    shutil.copyfile(src_path, dst_path)

# %%
## subir volumen
##for fi in `ls 20*`; do sox $fi /home/nidia/DILA/PICT-2020/seleccion-recortes-audio-nivacle-ago-2023/$fi vol 25 dB ; done
