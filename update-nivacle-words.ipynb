# %% [markdown]
# **2023-oct**
#
# Merge de palabras nivacle seleccionadas del corpus TCFiladelfia ((Palabras_Nivacle_TCFiladelfia.csv)[https://docs.google.com/spreadsheets/d/1resasym4ZmqI7xytQknT8Veeh_1tBgOfOU_mwCQ2EVE]) con seleccion de palabras de otras lenguas mataguayas ([palabras_en_comun_audios.csv](https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc)) para mostrar el sitio [pict-glotales](https://dila-ling.github.io/pict-glotales/)

# %%
import pandas as pd
import re
import numpy as np
import shutil

# %%
## IN
tcfildir = "../Nivacle/TCFiladelfia" ## Repertorio de TCFiladelfia
## OUT
ghdir = "../pict-glotales/_data" ## Repertorio del sitio Github

langs = ["wichi", "chorote", "nivacle", "maka"]

# %%
gsheet = "https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc/export?gid=1308046217&format=csv" ## CAICYT
#gsheet = "palabras_en_comun_audios.csv" ## BELERIAND

comun_audio =  pd.read_csv(gsheet)

# %%
comun_audio.head(5)
# Out:
#   Palabra   Lengua Español      Recorte              Archivo Formato  \
# 0   ɬokʲe  chorote    flor    ch_xlokje  BUCCA_A_02A-chorote     mp3
# 1    ɬawa  nivacle    flor     ni_lhavo  BUCCA_A_02A-nivacle     mp3
# 2   ɬawoʔ    wichi    flor    wi_lhaawo    BUCCA_A_02A-wichi     mp3
# 3  ɬop'om     maka    flor  ma_lh_op_om       MCA001R024I002     wav
# 4    ɬaʔa  chorote   fruta     ch_lha_a  BUCCA_A_02A-chorote     mp3
#
#   Inicio (sg)    Fin (sg) Código         Cita Audio  ...  \
# 0  192.746547  193.744485  B1969        Bucca, 1969  ...
# 1   14.692968    15.58418  B1969        Bucca, 1969  ...
# 2   69.969004   70.856474  B1969        Bucca, 1969  ...
# 3     222.903     223.945  G1985  Gerzenstein, 1985  ...
# 4  116.010337   116.77192  B1969        Bucca, 1969  ...
#
#                                   Cita Bibliográfica  Herramienta  \
# 0  Bucca, Salvador. “Elicitaciones en lenguas cho...     Audacity
# 1  Bucca, Salvador. “Elicitaciones en lenguas cho...     Audacity
# 2  Bucca, Salvador. “Elicitaciones en lenguas cho...     Audacity
# 3  Gerzenstein, Ana. (1985). Elicitación. Texas, ...  Transcriber
# 4  Bucca, Salvador. “Elicitaciones en lenguas cho...     Audacity
#
#   Transcriptorx    Tanda Revisorx     Fuente        Consultante  \
# 0            NH  2019-06       AG  DILA repo    Manuel González
# 1            NH  2019-06       AG  DILA repo          José Ampú
# 2            NH  2019-06       AG  DILA repo    Wilfredo Ibarra
# 3            MD  2019-06       AG      AILLA  T'semhej, Andrés
# 4            NH  2019-06       AG  DILA repo    Manuel González
#
#                                    Comunidad    Latitud   Longitud
# 0  Misión La Paz, Santa Victoria Este, Salta -22.368465 -62.561983
# 1  Misión La Paz, Santa Victoria Este, Salta -22.368465 -62.561983
# 2  Misión La Paz, Santa Victoria Este, Salta -22.368465 -62.561983
# 3                         Asunción, Paraguay -25.296674 -57.680663
# 4  Misión La Paz, Santa Victoria Este, Salta -22.368465 -62.561983
#
# [5 rows x 21 columns]

# %%
## Leemos csv de datos actuales en sitio github
mataguayas_comp_audio = pd.read_csv(f"{ghdir}/mataguayas-comparadas-audio.csv")
#mataguayas_comp_audio

# %%
## Leemos datos nuevos (subidos previamente a GDrive Palabras_Nivacle_TCFiladelfia)
#gsheet = "https://docs.google.com/spreadsheets/d/1resasym4ZmqI7xytQknT8Veeh_1tBgOfOU_mwCQ2EVE/export?gid=0&format=csv" ## CAICYT
gsheet = "Palabras_Nivacle_TCFiladelfia.csv" ## BELERIAND
nivacle_select =  pd.read_csv(gsheet)
## seleccionamos las filas con la info revisada por AG y NH
nivacle_select = nivacle_select[:18]
nivacle_select.head(5)
# Out:
#       Español      Palabra              ID Audio  Inicio (sg)  Fin (sg)  \
# 0        yica      k͡lisaʔ  2010_07_01_SR_AG_002          NaN       NaN
# 1  mi sobrino   jifak͡lʔa     20120308_FR_AG_070          NaN       NaN
# 2  mi sobrina  jifakt͡ʃeʔe    20120308_FR_AG_069          NaN       NaN
# 3         vos     aβa̰t͡ʃa    20170709_TS_AG_069          NaN       NaN
# 4      sombra       ɬaxpek    20120505_FR_AG_063          NaN       NaN
#
#     Lengua Transcriptorx Herramienta    Tanda Repositorio  Código  \
# 0  nivacle            AG        Word  2023-08    DILA inv  Gu2010
# 1  nivacle            AG        Word  2023-08    DILA inv  Gu2012
# 2  nivacle            AG        Word  2023-08    DILA inv  Gu2012
# 3  nivacle            AG        Word  2023-08    DILA inv  Gu2011
# 4  nivacle            AG        Word  2023-08    DILA inv  Gu2012
#
#        Cita Audio                                 Cita Bibliográfica  \
# 0  Gutiérrez_2010  Gutiérrez, Analía (2010) Trabajo de campo sobr...
# 1  Gutiérrez_2012  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 2  Gutiérrez_2012  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 3  Gutiérrez_2011  Gutiérrez, Analía (2011) Trabajo de campo sobr...
# 4  Gutiérrez_2012  Gutiérrez, Analía (2012) Trabajo de campo sobr...
#
#        Consultante                                 Original_audiopath  \
# 0  Elizabeth Rojas  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 1    Félix Ramírez  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 2    Félix Ramírez  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 3    Félix Ramírez  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
# 4    Félix Ramírez  DILA/Nivacle/Audios-TCFiladelfia/TCFiladelfiaA...
#
#                                         Recorte_path Match_type
# 0  /home/nidia/DILA/pict-glotales/assets/audio/20...       Full
# 1  /home/nidia/DILA/pict-glotales/assets/audio/20...       Full
# 2  /home/nidia/DILA/pict-glotales/assets/audio/20...       Full
# 3  ../pict-glotales/assets/audio/20170709_TS_AG_0...       Full
# 4  /home/nidia/DILA/pict-glotales/assets/audio/20...       Full

# %%
comun_audio.columns
# Out:
# Index(['Palabra', 'Lengua', 'Español', 'Recorte', 'Archivo', 'Formato',
#        'Inicio (sg)', 'Fin (sg)', 'Código', 'Cita Audio', 'Referencia cruzada',
#        'Cita Bibliográfica', 'Herramienta', 'Transcriptorx', 'Tanda',
#        'Revisorx', 'Fuente', 'Consultante', 'Comunidad', 'Latitud',
#        'Longitud'],
#       dtype='object')

# %%
## Renombrar
nivacle_select = nivacle_select.rename(columns={'ID Audio':'Archivo', 'Repositorio':'Fuente', 'Recorte_path':'Recorte'})

# %%
nivacle_select['Formato'] = 'wav'
nivacle_select['Referencia cruzada'] = np.nan
nivacle_select['Revisorx'] = 'AG'
nivacle_select['Comunidad'] = 'Uj’e Lhavos, Filadelfia, Paraguay'
nivacle_select['Latitud'] = -22.362071530572994
nivacle_select['Longitud'] = -60.050069732203234

# %%
## Reordenar y eliminar 
nivacle_select = nivacle_select[['Palabra', 'Lengua', 'Español','Recorte', 'Archivo', 'Formato',
                                 'Inicio (sg)', 'Fin (sg)', 'Código', 'Cita Audio', 'Referencia cruzada', 
                                 'Cita Bibliográfica', 'Herramienta', 'Transcriptorx', 'Tanda', 
                                 'Revisorx', 'Fuente', 'Consultante', 'Comunidad','Latitud', 'Longitud']]

# %%
## modificar para que solo aparezca ID del recorte
nivacle_select['Recorte'] = nivacle_select['Recorte'].str.replace("/home/nidia/DILA/pict-glotales/assets/audio/", "")
nivacle_select['Recorte'] = nivacle_select['Recorte'].str.replace("../pict-glotales/assets/audio/", "")
nivacle_select['Recorte'] = nivacle_select['Recorte'].str.replace(".wav", "")

nivacle_select['Cita Audio'] = nivacle_select['Cita Audio'].str.replace("Gutiérrez_", "Gutiérrez, ")

# %%
nivacle_select
# Out:
#         Palabra   Lengua     Español                       Recorte  \
# 0       k͡lisaʔ  nivacle        yica     2010_07_01_SR_AG_002_yica
# 1    jifak͡lʔa   nivacle  mi sobrino  20120308_FR_AG_070_misobrino
# 2   jifakt͡ʃeʔe  nivacle  mi sobrina  20120308_FR_AG_069_misobrina
# 3      aβa̰t͡ʃa  nivacle         vos        20170709_TS_AG_069_vos
# 4        ɬaxpek  nivacle      sombra     20120505_FR_AG_063_sombra
# 5         ek͡le  nivacle        loro     2010_08_14_SR_AG_020_loro
# 6     xiβeʔk͡la  nivacle        luna     2010_08_24_FR_AG_211_luna
# 7       nekxɑ̰k  nivacle        niño       20170404FR_AG_087_ninio
# 8          wɑ̰s  nivacle       cielo    2010_08_21_FR_AG_052_cielo
# 9           aɬu  nivacle      iguana          20120504GR037_iguana
# 10        fanxa  nivacle    langosta        20120313FR140_langosta
# 11     jikaʔwot  nivacle    mi panza        20170404FR156_mi_panza
# 12     jipɑʔkɑt  nivacle     mi mano         20190720FR056_mi_mano
# 13       satʼas  nivacle     cotorra         20170404FR038_cotorra
# 14       fa̰juk  nivacle   algarrobo       20110718JR072_algarrobo
# 15        ɬaβoʔ  nivacle      gusano          20110718JR107_gusano
# 16          ofo  nivacle      paloma          20110718JR012_paloma
# 17        jifoʔ  nivacle      mi pie          20100817MV011_mi_pie
#
#                  Archivo Formato  Inicio (sg)  Fin (sg)  Código  \
# 0   2010_07_01_SR_AG_002     wav          NaN       NaN  Gu2010
# 1     20120308_FR_AG_070     wav          NaN       NaN  Gu2012
# 2     20120308_FR_AG_069     wav          NaN       NaN  Gu2012
# 3     20170709_TS_AG_069     wav          NaN       NaN  Gu2011
# 4     20120505_FR_AG_063     wav          NaN       NaN  Gu2012
# 5   2010_08_14_SR_AG_020     wav          NaN       NaN  Gu2010
# 6   2010_08_24_FR_AG_211     wav          NaN       NaN  Gu2012
# 7   2017_04_04_FR_AG_087     wav          NaN       NaN  Gu2017
# 8   2010_08_21_FR_AG_052     wav          NaN       NaN  Gu2010
# 9   2012_05_04_GR_AG_037     wav          NaN       NaN  Gu2012
# 10  2012_03_13_FR_AG_140     wav          NaN       NaN  Gu2012
# 11  2017_04_04_FR_AG_156     wav          NaN       NaN  Gu2017
# 12  2019_07_20_FR_AG_056     wav          NaN       NaN  Gu2019
# 13  2017_04_04_FR_AG_038     wav          NaN       NaN  Gu2017
# 14  2017_07_07_FR_AG_071     wav          NaN       NaN  Gu2011
# 15  2011_07_18_JR_AG_107     wav          NaN       NaN  Gu2011
# 16  2011_07_18_JR_AG_012     wav          NaN       NaN  Gu2010
# 17  2010_08_17_MV_AG_011     wav          NaN       NaN  Gu2010
#
#         Cita Audio  ...                                 Cita Bibliográfica  \
# 0   Gutiérrez_2010  ...  Gutiérrez, Analía (2010) Trabajo de campo sobr...
# 1   Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 2   Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 3   Gutiérrez_2011  ...  Gutiérrez, Analía (2011) Trabajo de campo sobr...
# 4   Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 5   Gutiérrez_2010  ...  Gutiérrez, Analía (2010) Trabajo de campo sobr...
# 6   Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 7   Gutiérrez_2017  ...  Gutiérrez, Analía (2017) Trabajo de campo sobr...
# 8   Gutiérrez_2010  ...  Gutiérrez, Analía (2010) Trabajo de campo sobr...
# 9   Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 10  Gutiérrez_2012  ...  Gutiérrez, Analía (2012) Trabajo de campo sobr...
# 11  Gutiérrez_2017  ...  Gutiérrez, Analía (2017) Trabajo de campo sobr...
# 12  Gutiérrez_2019  ...  Gutiérrez, Analía (2019) Trabajo de campo sobr...
# 13  Gutiérrez_2017  ...  Gutiérrez, Analía (2017) Trabajo de campo sobr...
# 14  Gutiérrez_2011  ...  Gutiérrez, Analía (2011) Trabajo de campo sobr...
# 15  Gutiérrez_2011  ...  Gutiérrez, Analía (2011) Trabajo de campo sobr...
# 16  Gutiérrez_2010  ...  Gutiérrez, Analía (2010) Trabajo de campo sobr...
# 17  Gutiérrez_2010  ...  Gutiérrez, Analía (2010) Trabajo de campo sobr...
#
#    Herramienta Transcriptorx    Tanda Revisorx    Fuente       Consultante  \
# 0         Word            AG  2023-08       AG  DILA inv   Elizabeth Rojas
# 1         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 2         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 3         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 4         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 5         Word            AG  2023-08       AG  DILA inv        Sara Rojas
# 6         Word            AG  2023-08       AG  DILA inv  Graciano Ramírez
# 7         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 8         Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 9         Word            AG  2023-08       AG  DILA inv  Graciano Ramírez
# 10        Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 11        Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 12        Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 13        Word            AG  2023-08       AG  DILA inv     Félix Ramírez
# 14        Word            AG  2023-08       AG  DILA inv        José Rojas
# 15        Word            AG  2023-08       AG  DILA inv        José Rojas
# 16        Word            AG  2023-08       AG  DILA inv        José Rojas
# 17        Word            AG  2023-08       AG  DILA inv   Mauricio Valdez
#
#                             Comunidad    Latitud  Longitud
# 0   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 1   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 2   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 3   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 4   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 5   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 6   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 7   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 8   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 9   Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 10  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 11  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 12  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 13  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 14  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 15  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 16  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 17  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
#
# [18 rows x 21 columns]

# %%
nivacle_select.to_csv("nivacle_nuevas.csv", index=False)

# %% [markdown]
# ## Actualización del 26 de octubre
#
# Analía Gutiérrez
#
# 25 oct 2023, 14:41 (hace 1 día)
#
# Te cuento que corté 27 palabras nivacle. Las transcripciones, glosa y nombre de archivo están subidos a la [planilla de audios en común](https://docs.google.com/spreadsheets/d/1GtliM_yutOBnWaferOmQjVNLt_xOxz56rst6ZR9MkXc/edit#gid=1308046217) (líneas 112 a 137). Los audios están subidos a la carpeta [Nivacle_Audios_Gutierrez/Audios Octubre 2023](https://drive.google.com/drive/u/1/folders/1VFR2QhuHx8kOxtt2eytc6wjmPt7qp2q7)
#
# Aclaración:
# El audio y la transcripción para  "cotorra" (línea 107 del excel)  y que tenía una forma no comparable, tenés que volver a subirlos. Yo ya cambié los metadatos y en la carpeta encontrarás el audio para subirlo.
#
# Entonces, el listado de tareas para la parte nivacle:
#
# 1) Completar y normalizar los metadatos para 26 palabras (de cotorra ya está)
# 2) Subir las transcripciones y audios de 27 palabras (incluida cotorra)
# 3) Ajustar el volumen de todos los audios según criterio que habías adoptado
# 4) La forma para "aire" está en TC Filadelfia pero no tengo ese audio en mi máquina. Fijáte por favor si lo tenés ( algo parecido ya había pasado). Necesito que cortes el audio  y completes los metadatos

# %%
## 26 oct
comun_audio[112:]
# Out:
#           Palabra   Lengua           Español  \
# 112        jikfeʔ  nivacle          mi oreja
# 113      jiɬḭβte  nivacle        mi corazón
# 114       jitɑseχ  nivacle            mi ojo
# 115       -tʃitaʔ  nivacle     hermana mayor
# 116    jit͡ʃ'iniʃ  nivacle     hermano menor
# 117         βosej  nivacle              nube
# 118        ɬaʔβoʔ  nivacle         su cuello
# 119     t'afkatoʔ  nivacle           su codo
# 120         nuʔut  nivacle             tarde
# 121    jit͡ʃ'inxɑ  nivacle  mi hermana menor
# 122        ak͡loχ  nivacle             mucho
# 123        jiβɬiʔ  nivacle       mi costilla
# 124      a̰kxijuk  nivacle             árbol
# 125  aβa̰tt͡ʃeʔeɬ  nivacle           ustedes
# 126       k'akxoʔ  nivacle       quirquincho
# 127          ɬɑse  nivacle           su hija
# 128        jinɑ̰t  nivacle              agua
# 129        jit'oχ  nivacle            mi tía
# 130         ɬtako  nivacle           su cara
# 131         βosok  nivacle          mariposa
# 132   xunkuk͡la̰j  nivacle               sol
# 133      ɬaʔβojej  nivacle            sangre
# 134          jɑse  nivacle           mi hija
# 135       xapeʔja  nivacle           escucho
# 136       βatajaɬ  nivacle              aire
#
#                                  Recorte             Archivo Formato  \
# 112         2010_07_04_FR_AG_045_mioreja                 NaN     wav
# 113       2010_07_04_FR_AG_048_micorazon                 NaN     wav
# 114           2010_07_04_FR_AG_059_miojo                 NaN     wav
# 115    2010_08_17_FR_AG_067_hermanamayor                 NaN     wav
# 116  2010_08_17_MV_AG_068_mihermanomenor                 NaN     wav
# 117            2010_08_21_FR_AG_050_nube                 NaN     wav
# 118        2010_08_24_FR_AG_183_sucuello                 NaN     wav
# 119            2010_08_24_FR_AG_192_codo                 NaN     wav
# 120           2010_08_31_FR_AG_042_tarde                 NaN     wav
# 121  2011_07_08_ER_AG_071_mihermanamenor                 NaN     wav
# 122           2011_07_11_FR_AG_194_mucho                 NaN     wav
# 123      2011_07_11_FR_AG_203_micostilla                 NaN     wav
# 124           2011_07_12_FR_AG_075_arbol                 NaN     wav
# 125             2011_07_12_FR_AG_ustedes                 NaN     wav
# 126       20120308_FR_AG_003_quirquincho                 NaN     wav
# 127            20120313_FR_AG_136_suhija                 NaN     wav
# 128              20120315_FR_AG_041_agua                 NaN     wav
# 129             20120316_FR_AG_091_mitia                 NaN     wav
# 130            20120317_FR_AG_003_sucara                 NaN     wav
# 131          20120505_FR_AG_033_mariposa                 NaN     wav
# 132               20170407_FR_AG_061_sol                 NaN     wav
# 133            20170710_FR_AG_018_sangre                 NaN     wav
# 134           20190723_TeS_AG_025_mihija                 NaN     wav
# 135           20170407_FR_AG_019_escucho                 NaN     wav
# 136              20120514_FR_AG_169_aire  20120514_FR_AG_169     wav
#
#     Inicio (sg) Fin (sg) Código Cita Audio  ...  \
# 112         NaN      NaN    NaN        NaN  ...
# 113         NaN      NaN    NaN        NaN  ...
# 114         NaN      NaN    NaN        NaN  ...
# 115         NaN      NaN    NaN        NaN  ...
# 116         NaN      NaN    NaN        NaN  ...
# 117         NaN      NaN    NaN        NaN  ...
# 118         NaN      NaN    NaN        NaN  ...
# 119         NaN      NaN    NaN        NaN  ...
# 120         NaN      NaN    NaN        NaN  ...
# 121         NaN      NaN    NaN        NaN  ...
# 122         NaN      NaN    NaN        NaN  ...
# 123         NaN      NaN    NaN        NaN  ...
# 124         NaN      NaN    NaN        NaN  ...
# 125         NaN      NaN    NaN        NaN  ...
# 126         NaN      NaN    NaN        NaN  ...
# 127         NaN      NaN    NaN        NaN  ...
# 128         NaN      NaN    NaN        NaN  ...
# 129         NaN      NaN    NaN        NaN  ...
# 130         NaN      NaN    NaN        NaN  ...
# 131         NaN      NaN    NaN        NaN  ...
# 132         NaN      NaN    NaN        NaN  ...
# 133         NaN      NaN    NaN        NaN  ...
# 134         NaN      NaN    NaN        NaN  ...
# 135         NaN      NaN    NaN        NaN  ...
# 136         NaN      NaN    NaN        NaN  ...
#
#                                     Cita Bibliográfica Herramienta  \
# 112  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 113  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 114  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 115  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 116  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 117  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 118  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 119  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 120  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 121  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 122  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 123  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 124  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 125  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 126  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 127  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 128  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 129  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 130  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 131  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 132  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 133  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 134  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 135  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
# 136  Gutiérrez, Analía (2010) Trabajo de campo sobr...        Word
#
#     Transcriptorx    Tanda Revisorx    Fuente Consultante  \
# 112            AG  2023-08       AG  DILA inv         NaN
# 113            AG  2023-08       AG  DILA inv         NaN
# 114            AG  2023-08       AG  DILA inv         NaN
# 115            AG  2023-08       AG  DILA inv         NaN
# 116            AG  2023-08       AG  DILA inv         NaN
# 117            AG  2023-08       AG  DILA inv         NaN
# 118            AG  2023-08       AG  DILA inv         NaN
# 119            AG  2023-08       AG  DILA inv         NaN
# 120            AG  2023-08       AG  DILA inv         NaN
# 121            AG  2023-08       AG  DILA inv         NaN
# 122            AG  2023-08       AG  DILA inv         NaN
# 123            AG  2023-08       AG  DILA inv         NaN
# 124            AG  2023-08       AG  DILA inv         NaN
# 125            AG  2023-08       AG  DILA inv         NaN
# 126            AG  2023-08       AG  DILA inv         NaN
# 127            AG  2023-08       AG  DILA inv         NaN
# 128            AG  2023-08       AG  DILA inv         NaN
# 129            AG  2023-08       AG  DILA inv         NaN
# 130            AG  2023-08       AG  DILA inv         NaN
# 131            AG  2023-08       AG  DILA inv         NaN
# 132            AG  2023-08       AG  DILA inv         NaN
# 133            AG  2023-08       AG  DILA inv         NaN
# 134            AG  2023-08       AG  DILA inv         NaN
# 135            AG  2023-08       AG  DILA inv         NaN
# 136            AG  2023-08       AG  DILA inv         NaN
#
#                              Comunidad    Latitud  Longitud
# 112  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 113  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 114  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 115  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 116  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 117  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 118  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 119  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 120  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 121  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 122  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 123  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 124  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 125  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 126  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 127  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 128  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 129  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 130  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 131  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 132  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 133  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 134  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 135  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
# 136  Uj’e Lhavos, Filadelfia, Paraguay -22.362072 -60.05007
#
# [25 rows x 21 columns]

# %%
nuevas_niv1 = comun_audio[112:]

# %%
def norm(s):
    return s.rsplit('_', 1)[0]#.replace('AG', '').replace('_', '')

nuevas_niv['Archivo'] = nuevas_niv['Recorte'].map(norm)
# Out:
# /home/nidia/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
def find_year(s):
    return s.split('_')[0]

informantes = {
    'AC': 'Andres Crespo',
    'AJ': 'Agustín Juárez',
    'CS': 'Celestina Sacarías',
    'E': 'Ernestina',
    'ER': 'Elizabeth Rojas',
    'FR': 'Félix Ramírez',
    'FAR': 'Faustino Ramírez',
    'GR': 'Graciano Ramírez',
    'JR': 'José Rojas',
    'MV': 'Mauricio Valdez',
    'SD': 'Sofía Díaz', #'Chula'    
    'SR': 'Sara Rojas', #'Sara'
    'TS': 'Teresita Sánchez',
    'TeS': 'Teo Servín'
}

def find_spk(s):
    return s.split('_')[-2]
    
#nuevas_niv['Código'] = 'Gu'+nuevas_niv['Recorte'].map(find_year)
#nuevas_niv['Cita Audio'] = "Gutiérrez, "+nuevas_niv['Recorte'].map(find_year)
#nuevas_niv['Cita Audio'] = nuevas_niv['Recorte'].map(findspk)

nuevas_niv['Recorte'].map(find_spk)
# Out:
# 112              059
# 113              067
# 114              068
# 115              050
# 116              183
# 117              192
# 118              042
# 119              071
# 120              194
# 121              203
# 122              075
# 123    20110712FR071
# 124              003
# 125              136
# 126              041
# 127              091
# 128              003
# 129              033
# 130              120
# 131              061
# 132              088
# 133              018
# 134              025
# 135              019
# 136              169
# Name: Recorte, dtype: object

# %%
comun_audio.columns
# Out:
# Index(['Palabra', 'Lengua', 'Español', 'Recorte', 'Archivo', 'Formato',
#        'Inicio (sg)', 'Fin (sg)', 'Código', 'Cita Audio', 'Referencia cruzada',
#        'Cita Bibliográfica', 'Herramienta', 'Transcriptorx', 'Tanda',
#        'Revisorx', 'Fuente', 'Consultante', 'Comunidad', 'Latitud',
#        'Longitud'],
#       dtype='object')

# %%
mataguayas_comp_audio.columns
# Out:
# Index(['espanol', 'wichi', 'fuente_wichi', 'audio_wichi', 'chorote',
#        'fuente_chorote', 'audio_chorote', 'nivacle', 'fuente_nivacle',
#        'audio_nivacle', 'maka', 'fuente_maka', 'audio_maka'],
#       dtype='object')
